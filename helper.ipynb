# %%
import pandas as pd
dataset_df = pd.read_csv("data/iris.csv")
errors_df = pd.read_csv("data/errors.csv")
errors_df.rename(columns={'0': 0, '1': 1, '2': 2}, inplace=True)

# %%
from functions import *
df_dict = subgroup_discovery(dataset_df=dataset_df, errors_df=errors_df, number_of_classes=3)
# Out:
# Mining relevant subgroups...
# Mining relevant subgroups...
# Mining relevant subgroups...
# /home/lfrf/ufmg/poc/uncertainty-regions/venv/lib/python3.10/site-packages/pysubgroup/numeric_target.py:85: RuntimeWarning: divide by zero encountered in scalar divide
#   statistics["median_sg"] / statistics["median_dataset"]
# /home/lfrf/ufmg/poc/uncertainty-regions/venv/lib/python3.10/site-packages/pysubgroup/numeric_target.py:85: RuntimeWarning: invalid value encountered in scalar divide
#   statistics["median_sg"] / statistics["median_dataset"]
# /home/lfrf/ufmg/poc/uncertainty-regions/venv/lib/python3.10/site-packages/pysubgroup/numeric_target.py:85: RuntimeWarning: divide by zero encountered in scalar divide
#   statistics["median_sg"] / statistics["median_dataset"]
# /home/lfrf/ufmg/poc/uncertainty-regions/venv/lib/python3.10/site-packages/pysubgroup/numeric_target.py:85: RuntimeWarning: invalid value encountered in scalar divide
# ...

# %%
for cls in range(3):
    df_dict[str(cls)].subgroup = df_dict[str(cls)].subgroup.astype(str)

# %%
df_dict['0']
# Out:
#      quality                                           subgroup  size_sg  \
# 0   0.019600   petal length (cm)<1.50 AND sepal width (cm)<2.70        1
# 1   0.019600  petal width (cm): [1.50:1.90[ AND sepal length...        1
# 2   0.013576  sepal length (cm): [5.0:5.60[ AND sepal width ...        2
# 3   0.010854    sepal length (cm)<5.0 AND sepal width (cm)<2.70        3
# 4   0.008050  petal length (cm): [3.90:4.70[ AND sepal lengt...        5
# 5   0.006501  petal length (cm): [3.90:4.70[ AND sepal width...        7
# 6   0.005467  petal length (cm): [3.90:4.70[ AND petal width...        9
# 7   0.005467  petal width (cm): [1.50:1.90[ AND sepal width ...        9
# 8   0.005060  petal width (cm): [0.20:1.20[ AND sepal width ...       10
# 9   0.004714  petal length (cm)<1.50 AND petal width (cm): [...       21
# 10  0.004200  petal length (cm): [1.50:3.90[ AND sepal lengt...        4
# 11  0.004200  sepal length (cm): [5.60:6.10[ AND sepal width...        4
# ...
